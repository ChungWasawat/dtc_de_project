# %%
import pandas as pd

# %%
path = "D:\\data\\project\\"
data = "201901-citibike-tripdata.csv.zip"

df = pd.read_csv(f"{path}{data}", compression="zip")

# %%
df
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3               2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...              ...                       ...                       ...
# 967282           291  2019-01-31 17:33:26.4490  2019-01-31 17:38:17.8940
# 967283           437  2019-01-31 18:57:45.3380  2019-01-31 19:05:02.4970
# 967284           173  2019-01-31 19:11:41.1930  2019-01-31 19:14:34.3350
# 967285           244  2019-01-31 20:54:51.1440  2019-01-31 20:58:55.3100
# 967286           387  2019-01-31 23:38:42.1770  2019-01-31 23:45:09.4520
#
#         start station id           start station name  start station latitude  \
# ...

# %%
df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %% [markdown]
# # transform
# ### convert to datetime

# %%
df['starttime'] = pd.to_datetime(df['starttime'])
df['stoptime'] = pd.to_datetime(df['stoptime'])
df.dtypes
# Out:
# tripduration                        int64
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# start station id                  float64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# dtype: object

# %% [markdown]
# ### convert gender number to string

# %%
def changeGender(num:int) -> str:
    if num == 0:
        return "unknown"
    elif num == 1:
        return "male"
    elif num == 2:
        return "female"

# %%
df['gender'] = df['gender'].apply(changeGender)

# %%
df['gender'].unique()
# Out:
# array(['male', 'female', 'unknown'], dtype=object)

# %%
df.dtypes
# Out:
# tripduration                        int64
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# start station id                  float64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                             object
# dtype: object

# %% [markdown]
# ### find na in data frame

# %%
df.isnull().sum().sum()
# Out:
# 72

# %%
df.isnull().sum()
# Out:
# tripduration                0
# starttime                   0
# stoptime                    0
# start station id           18
# start station name         18
# start station latitude      0
# start station longitude     0
# end station id             18
# end station name           18
# end station latitude        0
# end station longitude       0
# bikeid                      0
# usertype                    0
# birth year                  0
# gender                      0
# dtype: int64

# %%
df1 = df
df1['null'] = df1['start station id'].isnull()
df1[df1['null']==True]
# Out:
#         tripduration               starttime                stoptime  \
# 248483          2358 2019-01-08 13:48:13.812 2019-01-08 14:27:32.016
# 249690          3358 2019-01-08 14:29:31.515 2019-01-08 15:25:29.713
# 336359           596 2019-01-10 14:35:39.212 2019-01-10 14:45:35.413
# 337008           816 2019-01-10 14:56:38.425 2019-01-10 15:10:14.812
# 396461           393 2019-01-12 12:36:01.144 2019-01-12 12:42:34.952
# 406295           214 2019-01-12 17:11:01.711 2019-01-12 17:14:36.542
# 407649          2949 2019-01-12 17:59:16.413 2019-01-12 18:48:26.240
# 507355           807 2019-01-15 20:49:27.612 2019-01-15 21:02:55.511
# 579801          2631 2019-01-17 18:10:35.913 2019-01-17 18:54:27.315
# 661484          2885 2019-01-21 00:17:02.710 2019-01-21 01:05:07.913
# 666099           560 2019-01-21 13:53:24.114 2019-01-21 14:02:44.711
# 666235           419 2019-01-21 14:05:00.455 2019-01-21 14:11:59.913
# 666393           484 2019-01-21 14:17:44.111 2019-01-21 14:25:48.512
# ...
